# %% [markdown]
# # [Notebook Title]
#
# **Module:** [Module Number and Name]
# **Lab:** [Task Number]
# **Estimated Time:** [X hours]
#
# ---
#
# ## Objectives
#
# By the end of this notebook, you will:
# - [ ] Objective 1
# - [ ] Objective 2
# - [ ] Objective 3
#
# ---

# %% [markdown]
# ## Setup
#
# First, let's verify our environment and import required libraries.

# %%
# Environment check
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import time

# Set random seeds for reproducibility
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)

# Plotting settings
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

# %% [markdown]
# ---
#
# ## Part 1: [Section Title]
#
# [Description of what this section covers]

# %%
# Your code here

# %% [markdown]
# ### Observations
#
# [Document your observations here]

# %% [markdown]
# ---
#
# ## Part 2: [Section Title]
#
# [Description]

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Part 3: [Section Title]
#
# [Description]

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Results Summary
#
# | Metric | Value |
# |--------|-------|
# | Metric 1 | |
# | Metric 2 | |
# | Metric 3 | |

# %% [markdown]
# ---
#
# ## Key Takeaways
#
# 1. **Takeaway 1:** [What you learned]
# 2. **Takeaway 2:** [What you learned]
# 3. **Takeaway 3:** [What you learned]
#
# ---

# %% [markdown]
# ## Cleanup

# %%
# Clear GPU memory
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print(f"GPU memory allocated: {torch.cuda.memory_allocated() / 1e9:.2f} GB")

# %% [markdown]
# ---
#
# ## Checklist
#
# Before moving on, verify:
#
# - [ ] Completed all code sections
# - [ ] Documented observations
# - [ ] Filled in results summary
# - [ ] Saved notebook with outputs
#
# **Next:** [Link to next notebook or module]
